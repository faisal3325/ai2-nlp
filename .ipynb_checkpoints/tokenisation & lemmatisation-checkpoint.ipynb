# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc_object = '"Mr. O\'Neill thinks that the boys\' stories about Chile\'s capital aren\'t amusing"'

# %%
print(doc_object)
# Out:
# "Mr. O'Neill thinks that the boys' stories about Chile's capital aren't amusing"

# %%
nlp_sentence = nlp(doc_object)
nlp_sentence
# Out:
# "Mr. O'Neill thinks that the boys' stories about Chile's capital aren't amusing"

# %%
for token in nlp_sentence:
    print(token.text, token.pos_, end=" | ")
# Out:
# " PUNCT | Mr. PROPN | O'Neill PROPN | thinks VERB | that ADP | the DET | boys NOUN | ' PART | stories NOUN | about ADP | Chile PROPN | 's PART | capital NOUN | are VERB | n't ADV | amusing ADJ | " PUNCT |

# %%
sentence = "Access our website between 9 a.m. and 1 p.m. every weekend at www.lyit.ie."

# %%
nlp_sentence = nlp(sentence)
nlp_sentence

for token in nlp_sentence:
    print(token.text)
# Out:
# Access
# our
# website
# between
# 9
# a.m.
# and
# 1
# p.m.
# every
# weekend
# at
# www.lyit.ie
# .

# %%
sentence = "I live about 20km from here. A taxi will cost around £50."

# %%
nlp_sentence = nlp(sentence)
nlp_sentence

for token in nlp_sentence:
    print(token.text)
# Out:
# I
# live
# about
# 20
# km
# from
# here
# .
# A
# taxi
# will
# cost
# around
# £
# 50
# .

# %%
doc_object = nlp(u"I really like to work with words!")

for token in doc_object:
    print(token)
# Out:
# I
# really
# like
# to
# work
# with
# words
# !

# %%
doc_object[0]
# Out:
# I

# %%
doc_object[3:6]
# Out:
# to work with

# %%
doc_object[-2:]
# Out:
# words!

# %%
doc_object = nlp(u"Samsung in Ireland are pleased with their new folding screen that they released after a $9 million investment.")

print(doc_object.ents)
for entity in doc_object.ents:
    print(entity)
# Out:
# (Samsung, Ireland, $9 million)
# Samsung
# Ireland
# $9 million

# %%
doc_object = nlp(u"I like my car")

print(doc_object.ents)
for entity in doc_object.ents:
    print(entity)
# Out:
# ()

# %%
def show_entity_info(doc_object):
    if doc_object:
        for entity in doc_object.ents:
            print(f"{entity.text:{30}} {entity.label_:{30}} {spacy.explain(entity.label_)}")
    else:
        print("No entities found in text.")

# %%
show_entity_info(doc_object)
# Out:
# Samsung ORG        Companies, agencies, institutions, etc.
# Ireland GPE        Countries, cities, states
# $9 million MONEY      Monetary values, including unit

# %%
doc_object = nlp(u"Autonomous cars shift insurance liability toward manufacturers")

# %%
for chunk in doc_object.noun_chunks:
    print(f"{chunk.text:{20}} {chunk.root.text:{20}} {spacy.explain(chunk.root.dep_):{25}} {chunk.root.head}")
# Out:
# Autonomous cars      cars                 nominal subject           shift
# insurance liability  liability            direct object             shift
# manufacturers        manufacturers        object of preposition     toward

# %%
from spacy import displacy

# %%
displacy.render(doc_object, style='dep', jupyter=True, options={"distance":100, "color":"Blue", "arrow_stroke":4, "arrow_spacing":20, "word_spacing":50})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="750" height="304.0" style="max-width: none; height: 304.0px; color: Blue; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Autonomous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">cars</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">shift</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">insurance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">liability</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">toward</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">manufacturers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="4px" d="M70,154.0 C70,104.0 140.0,104.0 140.0,154.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,156.0 L62,144.0 78,144.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="4px" d="M170,154.0 C170,104.0 240.0,104.0 240.0,154.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,156.0 L162,144.0 178,144.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="4px" d="M370,154.0 C370,104.0 440.0,104.0 440.0,154.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,156.0 L362,144.0 378,144.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="4px" d="M270,154.0 C270,54.0 445.0,54.0 445.0,154.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,156.0 L453.0,144.0 437.0,144.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="4px" d="M270,154.0 C270,4.0 550.0,4.0 550.0,154.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550.0,156.0 L558.0,144.0 542.0,144.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="4px" d="M570,154.0 C570,104.0 640.0,104.0 640.0,154.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M640.0,156.0 L648.0,144.0 632.0,144.0" fill="currentColor"/>
# </g>
# </svg>

# %%
text_file = open("noun-chunks.txt")
noun_chunks = text_file.read()

# %%
print(noun_chunks)
# Out:
# When Sebastian Thrun started working on self-driving cars at Google in 2007, few people outside of the company took him seriously.
# "I can tell you very senior CEOs of major American car companies would shake my hand and turn away because I wasn't worth talking to," said Thrun, now the co-founder and CEO of online higher education startup Udacity, in an interview with Recode earlier this week.
# A little less than a decade later, dozens of self-driving startups have cropped up while automakers around the world clamor, wallet in hand, to secure their place in the fast-moving world of fully automated transportation.

# %%
doc_object = nlp(noun_chunks)

# %%
show_entity_info(doc_object)
# Out:
# Sebastian Thrun                PERSON                         People, including fictional
# Google                         ORG                            Companies, agencies, institutions, etc.
# 2007                           DATE                           Absolute or relative dates or periods
#
#                               GPE                            Countries, cities, states
# American                       NORP                           Nationalities or religious or political groups
# Thrun                          PERSON                         People, including fictional
# Recode                         ORG                            Companies, agencies, institutions, etc.
# earlier this week              DATE                           Absolute or relative dates or periods
#
#                               GPE                            Countries, cities, states
# less than a decade later       DATE                           Absolute or relative dates or periods
# dozens                         CARDINAL                       Numerals that do not fall under another type

# %%
displacy.render(doc_object, style='dep', jupyter=True, options={"distance":200, "color":"Blue", "arrow_stroke":4, "arrow_spacing":10, "word_spacing":30, "compact":True})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="21850" height="1494.0" style="max-width: none; height: 1494.0px; color: Blue; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">When</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Sebastian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">Thrun</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">started</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">working</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">self-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">driving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">cars</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">2007,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">few</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">outside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="3250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="3450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="3850">took</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="4050">him</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4050">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">seriously.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="4450">
# &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="4650">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4650">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="4850">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="5050">tell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="5250">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="5450">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="5650">senior</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="5850">CEOs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1434.0">
#     <tspan class="displacy-word" fill="currentColor" x="6050">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="6050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text

# %%
displacy.render(doc_object, style='ent', jupyter=True, options={"distance":200, "color":"Blue", "arrow_stroke":4, "arrow_spacing":10, "word_spacing":30, "compact":True})
# Out:
# <div class="entities" style="line-height: 2.5">When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Sebastian Thrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  started working on self-driving cars at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , few people outside of the company took him seriously.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# "I can tell you very senior CEOs of major
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  car companies would shake my hand and turn away because I wasn't worth talking to," said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Thrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , now the co-founder and CEO of online higher education startup Udacity, in an interview with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Recode
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     earlier this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# A little
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     less than a decade later
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     dozens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of self-driving startups have cropped up while automakers around the world clamor, wallet in hand, to secure their place in the fast-moving world of fully automated transportation.</div>
